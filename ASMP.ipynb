# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
start = datetime.datetime(2012,1,1)
end = datetime.datetime(2017,1,1)

# %%
tesla = web.DataReader("TSLA", 'yahoo', start, end)
ford = web.DataReader("F", 'yahoo', start, end)
gm = web.DataReader("GM", 'yahoo', start, end)

# %%
tesla.to_csv('Tesla_Stock.csv')
ford.to_csv('Ford_Stock.csv')
gm.to_csv('GM_Stock.csv')

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.468544
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.582618
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.777214
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.857739
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.918133

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269417
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714722
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652895

# %%
tesla['Open'].plot(label = 'Tesla', figsize = (15,7))
gm['Open'].plot(label = 'GM')
ford['Open'].plot(label = 'Ford')
plt.ylabel('Stock Price')
plt.title('Stock Prices of Tesla, GM and Ford')
plt.legend()

# %%
tesla['Volume'].plot(label = 'Tesla', figsize = (15,7))
gm['Volume'].plot(label = 'GM')
ford['Volume'].plot(label = 'Ford')
plt.ylabel('Volume Traded')
plt.legend()

# %%
ford.iloc[[ford['Volume'].argmax()]]
# Out:
#             High    Low   Open  Close       Volume  Adj Close
# Date
# 2013-12-18  16.0  15.17  15.99  15.65  220363000.0  10.981931

# %%
ford.iloc[470:520]['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla['Total Traded'] = tesla['Open']*tesla['Volume']
gm['Total Traded'] = gm['Open']*tesla['Volume']
ford['Total Traded'] = ford['Open']*tesla['Volume']

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  Total Traded
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450  2.421900e+07

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269417
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714722
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652895
#
#             Total Traded
# Date
# 2012-01-03  9.666161e+07
# 2012-01-04  6.631802e+07
# 2012-01-05  1.060803e+08
# 2012-01-06  1.097752e+08
# 2012-01-09  1.040520e+08

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.468544  5.104550e+07
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.582618  3.512807e+07
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.777214  5.696157e+07
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.857739  5.789581e+07
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.918133  5.305755e+07

# %%
tesla['Total Traded'].plot(label = 'Tesla', figsize = (15,7))
gm['Total Traded'].plot(label = 'GM')
ford['Total Traded'].plot(label = 'Ford')
plt.legend()
plt.ylabel("Total Traded")
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
tesla['Total Traded'].argmax()
# Out:
# 538

# %%
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#              High        Low  Open      Close     Volume  Adj Close  \
# Date
# 2014-02-25  51.84  45.689999  46.0  49.599998  163408500  49.599998
#
#             Total Traded
# Date
# 2014-02-25  7.516791e+09

# %%
gm['Open'].plot(label ='No Moving Average', figsize = (15,7))
gm['MA50'] = gm['Open'].rolling(50).mean()
gm['MA50'].plot(label = 'MA50')
gm['MA200'] = gm['Open'].rolling(200).mean()
gm['MA200'].plot(label = 'MA200')
plt.legend()

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
car_company = pd.concat([tesla['Open'], gm['Open'], ford['Open']], axis = 1)
car_company.columns = ['Tesla Open', 'GM Open', 'Ford Open']

# %%
scatter_matrix(car_company, figsize = (8,8), hist_kwds = {'bins':50})
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>]],
#       dtype=object)

# %%
# pip install --upgrade mplfinance

# %%
from mplfinance.original_flavor import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, DayLocator, MONDAY

ford_reset = ford.loc['2012-01':'2012-01'].reset_index()

ford_reset['date_ax'] = ford_reset['Date'].apply(lambda date: date2num(date))
ford_values = [tuple(vals) for vals in ford_reset[['date_ax', 'Open', 'High', 'Low', 'Close']].values]

mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
weekFormatter = DateFormatter('%b %d')
dayFormatter = DateFormatter('%d')

fig, ax = plt.subplots()
candlestick_ohlc(ax, ford_values, width = 0.6, colorup = 'g', colordown = 'r')
# Out:
# ([<matplotlib.lines.Line2D at 0x1da3c733b80>,
#   <matplotlib.lines.Line2D at 0x1da3c775df0>,
#   <matplotlib.lines.Line2D at 0x1da3c784460>,
#   <matplotlib.lines.Line2D at 0x1da3c784a90>,
#   <matplotlib.lines.Line2D at 0x1da3c78f100>,
#   <matplotlib.lines.Line2D at 0x1da3c78f730>,
#   <matplotlib.lines.Line2D at 0x1da3c78fd60>,
#   <matplotlib.lines.Line2D at 0x1da3c79d3d0>,
#   <matplotlib.lines.Line2D at 0x1da3c79da00>,
#   <matplotlib.lines.Line2D at 0x1da3c7aa070>,
#   <matplotlib.lines.Line2D at 0x1da3c7aa6a0>,
#   <matplotlib.lines.Line2D at 0x1da3c7aacd0>,
#   <matplotlib.lines.Line2D at 0x1da3c7b6340>,
#   <matplotlib.lines.Line2D at 0x1da3c7b6970>,
#   <matplotlib.lines.Line2D at 0x1da3c7b6fa0>,
#   <matplotlib.lines.Line2D at 0x1da3c7c4610>,
#   <matplotlib.lines.Line2D at 0x1da3c7c4c40>,
#   <matplotlib.lines.Line2D at 0x1da3c7d02b0>,
#   <matplotlib.lines.Line2D at 0x1da3c7d08e0>,
#   <matplotlib.lines.Line2D at 0x1da3c7d0f10>],
#  [<matplotlib.patches.Rectangle at 0x1da3c767940>,
#   <matplotlib.patches.Rectangle at 0x1da3c775f40>,
#   <matplotlib.patches.Rectangle at 0x1da3c7845b0>,
#   <matplotlib.patches.Rectangle at 0x1da3c784be0>,
#   <matplotlib.patches.Rectangle at 0x1da3c78f250>,
#   <matplotlib.patches.Rectangle at 0x1da3c78f880>,
#   <matplotlib.patches.Rectangle at 0x1da3c78feb0>,
#   <matplotlib.patches.Rectangle at 0x1da3c79d520>,
#   <matplotlib.patches.Rectangle at 0x1da3c79db50>,
#   <matplotlib.patches.Rectangle at 0x1da3c7aa1c0>,
#   <matplotlib.patches.Rectangle at 0x1da3c7aa7f0>,
#   <matplotlib.patches.Rectangle at 0x1da3c7aae20>,
#   <matplotlib.patches.Rectangle at 0x1da3c7b6490>,
#   <matplotlib.patches.Rectangle at 0x1da3c7b6ac0>,
#   <matplotlib.patches.Rectangle at 0x1da3c7b6fd0>,
#   <matplotlib.patches.Rectangle at 0x1da3c7c4760>,
#   <matplotlib.patches.Rectangle at 0x1da3c7c4d90>,
#   <matplotlib.patches.Rectangle at 0x1da3c7d0400>,
#   <matplotlib.patches.Rectangle at 0x1da3c7d0a30>,
#   <matplotlib.patches.Rectangle at 0x1da3c7d0fa0>])

# %% [markdown]
# # Daily Percentage Change

# %%
tesla['Returns'] = (tesla['Close'] / tesla['Close'].shift(1)) -1

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450  2.421900e+07
#
#              Returns
# Date
# 2012-01-03       NaN
# 2012-01-04 -0.013177
# 2012-01-05 -0.021292
# 2012-01-06 -0.007743
# 2012-01-09  0.012635

# %%
ford['Returns'] = (ford['Close'] / ford['Close'].shift(1)) -1
gm['Returns'] = (gm['Close'] / gm['Close'].shift(1)) -1

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.468544  5.104550e+07
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.582618  3.512807e+07
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.777214  5.696157e+07
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.857739  5.789581e+07
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.918133  5.305755e+07
#
#              Returns
# Date
# 2012-01-03       NaN
# 2012-01-04  0.015274
# 2012-01-05  0.025664
# 2012-01-06  0.010354
# 2012-01-09  0.007686

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269417
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714722
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652895
#
#             Total Traded  MA50  MA200   Returns
# Date
# 2012-01-03  9.666161e+07   NaN    NaN       NaN
# 2012-01-04  6.631802e+07   NaN    NaN  0.004751
# 2012-01-05  1.060803e+08   NaN    NaN  0.048227
# 2012-01-06  1.097752e+08   NaN    NaN  0.033829
# 2012-01-09  1.040520e+08   NaN    NaN -0.003490

# %%
ford['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
gm['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
tesla['Returns'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
tesla['Returns'].hist(bins=100, label = 'Tesla', alpha = 0.5, figsize = (13,6))
ford['Returns'].hist(bins=100, label = 'Ford', alpha = 0.5)
gm['Returns'].hist(bins=100, label ='GM', alpha = 0.5)
plt.legend()

# %%
tesla['Returns'].plot(kind = 'kde', label = 'Tesla', figsize=(15,6))
ford['Returns'].plot(kind = 'kde', label = 'Ford')
gm['Returns'].plot(kind = 'kde', label = 'GM')
plt.legend()

# %%
box_df = pd.concat([tesla['Returns'], gm['Returns'], ford['Returns']], axis =1)
box_df.columns = ['Tesla Returns', 'GM Returns', 'Ford Returns']
box_df.plot(kind = 'box', figsize = (16,6))
# Out:
# <AxesSubplot:>

# %%
scatter_matrix(box_df, figsize=(8,8), hist_kwds={'bins':50}, alpha=0.25)
# Out:
# array([[<AxesSubplot:xlabel='Tesla Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Tesla Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Tesla Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='GM Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='GM Returns'>],
#        [<AxesSubplot:xlabel='Tesla Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='GM Returns', ylabel='Ford Returns'>,
#         <AxesSubplot:xlabel='Ford Returns', ylabel='Ford Returns'>]],
#       dtype=object)

# %% [markdown]
# # Cumulative Return

# %%
tesla['Cumulative Return'] = (1 + tesla['Returns']).cumprod()

# %%
ford['Cumulative Return'] = (1 + ford['Returns']).cumprod()
gm['Cumulative Return'] = (1 + gm['Returns']).cumprod()

# %%
tesla.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  5.900  5.530  5.788  5.616  4640500      5.616  2.685921e+07
# 2012-01-04  5.734  5.500  5.642  5.542  3150500      5.542  1.777512e+07
# 2012-01-05  5.586  5.370  5.552  5.424  5027500      5.424  2.791268e+07
# 2012-01-06  5.558  5.282  5.440  5.382  4931500      5.382  2.682736e+07
# 2012-01-09  5.498  5.224  5.400  5.450  4485000      5.450  2.421900e+07
#
#              Returns  Cumulative Return
# Date
# 2012-01-03       NaN                NaN
# 2012-01-04 -0.013177           0.986823
# 2012-01-05 -0.021292           0.965812
# 2012-01-06 -0.007743           0.958333
# 2012-01-09  0.012635           0.970442

# %%
ford.head()
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded  \
# Date
# 2012-01-03  11.25  10.99  11.00  11.13  45709900.0   7.468544  5.104550e+07
# 2012-01-04  11.53  11.07  11.15  11.30  79725200.0   7.582618  3.512807e+07
# 2012-01-05  11.63  11.24  11.33  11.59  67877500.0   7.777214  5.696157e+07
# 2012-01-06  11.80  11.52  11.74  11.71  59840700.0   7.857739  5.789581e+07
# 2012-01-09  11.95  11.70  11.83  11.80  53981500.0   7.918133  5.305755e+07
#
#              Returns  Cumulative Return
# Date
# 2012-01-03       NaN                NaN
# 2012-01-04  0.015274           1.015274
# 2012-01-05  0.025664           1.041330
# 2012-01-06  0.010354           1.052111
# 2012-01-09  0.007686           1.060198

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2012-01-03  21.180000  20.750000  20.830000  21.049999   9321300.0  16.269417
# 2012-01-04  21.370001  20.750000  21.049999  21.150000   7856700.0  16.346703
# 2012-01-05  22.290001  20.959999  21.100000  22.170000  17880600.0  17.135054
# 2012-01-06  23.030001  22.240000  22.260000  22.920000  18234500.0  17.714722
# 2012-01-09  23.430000  22.700001  23.200001  22.840000  12084500.0  17.652895
#
#             Total Traded  MA50  MA200   Returns  Cumulative Return
# Date
# 2012-01-03  9.666161e+07   NaN    NaN       NaN                NaN
# 2012-01-04  6.631802e+07   NaN    NaN  0.004751           1.004751
# 2012-01-05  1.060803e+08   NaN    NaN  0.048227           1.053207
# 2012-01-06  1.097752e+08   NaN    NaN  0.033829           1.088836
# 2012-01-09  1.040520e+08   NaN    NaN -0.003490           1.085036

# %%
tesla['Cumulative Return'].plot(label='Tesla', figsize=(15,7))
ford['Cumulative Return'].plot(label='Ford')
gm['Cumulative Return'].plot(label='GM')
plt.title('Cumulative Return vs Time')
plt.legend()

# %% [markdown]
# ## Tesla showed the highest return for per dollar invested.
